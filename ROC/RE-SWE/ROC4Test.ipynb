# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
import time
from torch.utils.data import Subset
from sklearn.metrics import roc_auc_score, accuracy_score, matthews_corrcoef, recall_score, precision_score,auc
import time
from sklearn.metrics import roc_curve
import pandas as pd

import statsmodels.api as sm

# %%
def plot_roc_curve(fpr, tpr, label=None, color=None):

    plt.plot([0, 1], [0, 1], 'k--') 
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.2])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Roc Curves under Independent Test')
    
    lowess = sm.nonparametric.lowess(tpr, fpr, frac=0.2)  # 调整 frac 参数以控制平滑度
    x_fine = lowess[:, 0]
    y_fine = lowess[:, 1]

    plt.plot(x_fine, y_fine, color=color, lw=2, label=label)
    plt.legend(loc="lower right", fontsize='xx-small')

# %%
# ML

# XGB

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/XGB/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/XGB/y_test.npy') # 这里y_test指的就是y_test_label
fpr_xgb, tpr_xgb, thresholds_xgb = roc_curve(y_test, y_test_pred)
roc_auc_xgb = auc(fpr_xgb, tpr_xgb)

# SVM

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/SVM/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/SVM/y_test.npy') # 这里y_test指的就是y_test_label
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_test, y_test_pred)
roc_auc_svm = auc(fpr_svm, tpr_svm)

# RF

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/RF/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/RF/y_test.npy') # 这里y_test指的就是y_test_label
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_test_pred)
roc_auc_rf = auc(fpr_rf, tpr_rf)

# NB

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/NB/y_test_pred.npy') # 概率是0, 1, 0这样的
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/NB/y_test.npy') # 这里y_test指的就是y_test_label
fpr_nb, tpr_nb, thresholds_nb = roc_curve(y_test, y_test_pred)
roc_auc_nb = auc(fpr_nb, tpr_nb)

# LR

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/LR/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/LR/y_test.npy') # 这里y_test指的就是y_test_label
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_test_pred)
roc_auc_lr = auc(fpr_lr, tpr_lr)

# %%
# AlexNet

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/AlexNet/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/AlexNet/y_test.npy') # 这里y_test指的就是y_test_label
fpr_alexnet, tpr_alexnet, thresholds_alexnet = roc_curve(y_test, y_test_pred)
roc_auc_alexnet = auc(fpr_alexnet, tpr_alexnet)

# %%
# GoogLeNet

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/GoogLeNet/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/GoogLeNet/y_test.npy') # 这里y_test指的就是y_test_label
fpr_googlenet, tpr_googlenet, thresholds_googlenet = roc_curve(y_test, y_test_pred)
roc_auc_googlenet = auc(fpr_googlenet, tpr_googlenet)

# %%
# ResNet-34

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-34/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-34/y_test.npy') # 这里y_test指的就是y_test_label
fpr_resnet34, tpr_resnet34, thresholds_resnet34 = roc_curve(y_test, y_test_pred)
roc_auc_resnet34 = auc(fpr_resnet34, tpr_resnet34)

# %%
# ResNet-50

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-50/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-50/y_test.npy') # 这里y_test指的就是y_test_label
fpr_resnet50, tpr_resnet50, thresholds_resnet50 = roc_curve(y_test, y_test_pred)
roc_auc_resnet50 = auc(fpr_resnet50, tpr_resnet50)

# %%
# ResNet-101

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-101/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-101/y_test.npy') # 这里y_test指的就是y_test_label
fpr_resnet101, tpr_resnet101, thresholds_resnet101 = roc_curve(y_test, y_test_pred)
roc_auc_resnet101 = auc(fpr_resnet101, tpr_resnet101)

# %%
# ShuffleNet

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ShuffleNet/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ShuffleNet/y_test.npy') # 这里y_test指的就是y_test_label
fpr_shufflenet, tpr_shufflenet, thresholds_shufflenet = roc_curve(y_test, y_test_pred)
roc_auc_shufflenet = auc(fpr_shufflenet, tpr_shufflenet)

# %%
# VisionTransformer

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/ViT/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ViT/y_test.npy') # 这里y_test指的就是y_test_label
fpr_visiontransformer, tpr_visiontransformer, thresholds_visiontransformer = roc_curve(y_test, y_test_pred)
roc_auc_visiontransformer = auc(fpr_visiontransformer, tpr_visiontransformer)

# %%
# MobileNetV2

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileNetV2/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileNetV2/y_test.npy') # 这里y_test指的就是y_test_label
fpr_mobilenetv2, tpr_mobilenetv2, thresholds_mobilenetv2 = roc_curve(y_test, y_test_pred)
roc_auc_mobilenetv2 = auc(fpr_mobilenetv2, tpr_mobilenetv2)

# %%
# MobileNetV3_l

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileNetV3_l/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileNetV3_l/y_test.npy') # 这里y_test指的就是y_test_label
fpr_mobilenetv3_l, tpr_mobilenetv3_l, thresholds_mobilenetv3_l = roc_curve(y_test, y_test_pred)
roc_auc_mobilenetv3_l = auc(fpr_mobilenetv3_l, tpr_mobilenetv3_l)

# %%
# MobileNetV3_s

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileNetV3_s/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileNetV3_s/y_test.npy') # 这里y_test指的就是y_test_label
fpr_mobilenetv3_s, tpr_mobilenetv3_s, thresholds_mobilenetv3_s = roc_curve(y_test, y_test_pred)
roc_auc_mobilenetv3_s = auc(fpr_mobilenetv3_s, tpr_mobilenetv3_s)

# %%
# MobileViT_s

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileViT_s/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileViT_s/y_test.npy') # 这里y_test指的就是y_test_label
fpr_mobilevit_s, tpr_mobilevit_s, thresholds_mobilevit_s = roc_curve(y_test, y_test_pred)
roc_auc_mobilevit_s = auc(fpr_mobilevit_s, tpr_mobilevit_s)

# %%
# MobileViT_x_s

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileViT_x_s/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileViT_x_s/y_test.npy') # 这里y_test指的就是y_test_label
fpr_mobilevit_x_s, tpr_mobilevit_x_s, thresholds_mobilevit_x_s = roc_curve(y_test, y_test_pred)
roc_auc_mobilevit_x_s = auc(fpr_mobilevit_x_s, tpr_mobilevit_x_s)

# %%
# MobileViT_xx_s

y_test_pred = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileViT_xx_s/y_test_pred.npy')
y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileViT_xx_s/y_test.npy') # 这里y_test指的就是y_test_label
fpr_mobilevit_xx_s, tpr_mobilevit_xx_s, thresholds_mobilevit_xx_s = roc_curve(y_test, y_test_pred)
roc_auc_mobilevit_xx_s = auc(fpr_mobilevit_xx_s, tpr_mobilevit_xx_s)

# %%
plot_roc_curve(fpr_xgb, tpr_xgb, label=f'XGB (AUC = {roc_auc_xgb:.4f})', color='b')
plot_roc_curve(fpr_svm, tpr_svm, label=f'SVM (AUC = {roc_auc_svm:.4f})', color='g')
plot_roc_curve(fpr_rf, tpr_rf, label=f'RF (AUC = {roc_auc_rf:.4f})', color='r')
# plot_roc_curve(fpr_nb, tpr_nb, label=f'NB (AUC = {roc_auc_nb:.4f})', color='c')
plot_roc_curve(fpr_lr, tpr_lr, label=f'LR (AUC = {roc_auc_lr:.4f})', color='m')

plot_roc_curve(fpr_alexnet, tpr_alexnet, label=f'AlexNet (AUC = {roc_auc_alexnet:.4f})', color='y')
plot_roc_curve(fpr_googlenet, tpr_googlenet, label=f'GoogLeNet (AUC = {roc_auc_googlenet:.4f})', color='b')
plot_roc_curve(fpr_shufflenet, tpr_shufflenet, label=f'ShuffleNet (AUC = {roc_auc_shufflenet:.4f})', color='m')
plot_roc_curve(fpr_visiontransformer, tpr_visiontransformer, label=f'ViT (AUC = {roc_auc_visiontransformer:.4f})', color='y')

plot_roc_curve(fpr_resnet34, tpr_resnet34, label=f'ResNet-34 (AUC = {roc_auc_resnet34:.4f})', color='g')
plot_roc_curve(fpr_resnet50, tpr_resnet50, label=f'ResNet-50 (AUC = {roc_auc_resnet50:.4f})', color='r')
plot_roc_curve(fpr_resnet101, tpr_resnet101, label=f'ResNet-101 (AUC = {roc_auc_resnet101:.4f})', color='c')

plot_roc_curve(fpr_mobilenetv2, tpr_mobilenetv2, label=f'MobileNetV2 (AUC = {roc_auc_mobilenetv2:.4f})', color='g')
plot_roc_curve(fpr_mobilenetv3_l, tpr_mobilenetv3_l, label=f'MobileNetV3_l (AUC = {roc_auc_mobilenetv3_l:.4f})', color='r')
plot_roc_curve(fpr_mobilenetv3_s, tpr_mobilenetv3_s, label=f'MobileNetV3_s (AUC = {roc_auc_mobilenetv3_s:.4f})', color='c')

plot_roc_curve(fpr_mobilevit_s, tpr_mobilevit_s, label=f'MobileViT_s (AUC = {roc_auc_mobilevit_s:.4f})', color='m')
plot_roc_curve(fpr_mobilevit_x_s, tpr_mobilevit_x_s, label=f'MobileViT_x_s (AUC = {roc_auc_mobilevit_x_s:.4f})', color='y')
plot_roc_curve(fpr_mobilevit_xx_s, tpr_mobilevit_xx_s, label=f'MobileViT_xx_s (AUC = {roc_auc_mobilevit_xx_s:.4f})', color='y')

plt.savefig('/root/autodl-tmp/ROC/RE-SWE/ROC4Test.pdf', format='pdf')
plt.show()
# Out:
# /root/miniconda3/envs/py38/lib/python3.8/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),

# %%
# save in a table for R to generate smooth ROC curve
y_test_pred1 = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/XGB/y_test_pred.npy')
y_test_pred2 = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/SVM/y_test_pred.npy')
y_test_pred3 = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/RF/y_test_pred.npy')
y_test_pred4 = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/NB/y_test_pred.npy')
y_test_pred5 = np.load('/root/autodl-tmp/ROC/RE-SWE/ML/LR/y_test_pred.npy')

y_test_pred6 = np.load('/root/autodl-tmp/ROC/RE-SWE/AlexNet/y_test_pred.npy')
y_test_pred7 = np.load('/root/autodl-tmp/ROC/RE-SWE/GoogLeNet/y_test_pred.npy')
y_test_pred8 = np.load('/root/autodl-tmp/ROC/RE-SWE/ShuffleNet/y_test_pred.npy')
y_test_pred9 = np.load('/root/autodl-tmp/ROC/RE-SWE/ViT/y_test_pred.npy')

y_test_pred10 = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-34/y_test_pred.npy')
y_test_pred11 = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-50/y_test_pred.npy')
y_test_pred12 = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-101/y_test_pred.npy')

y_test_pred13 = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileNetV2/y_test_pred.npy')
y_test_pred14 = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileNetV3_l/y_test_pred.npy')
y_test_pred15 = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileNetV3_s/y_test_pred.npy')

y_test_pred16 = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileViT_s/y_test_pred.npy')
y_test_pred17 = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileViT_x_s/y_test_pred.npy')
y_test_pred18 = np.load('/root/autodl-tmp/ROC/RE-SWE/MobileViT_xx_s/y_test_pred.npy')

y_test = np.load('/root/autodl-tmp/ROC/RE-SWE/ResNet-34/y_test.npy')

data = np.column_stack((y_test, y_test_pred1, y_test_pred2, y_test_pred3, y_test_pred4, y_test_pred5, y_test_pred6, y_test_pred7, y_test_pred8, y_test_pred9, y_test_pred10, y_test_pred11, y_test_pred12, y_test_pred13, y_test_pred14, y_test_pred15, y_test_pred16, y_test_pred17, y_test_pred18))

np.savetxt('RE-SWE_ROC4Test.csv', 
           data,
           delimiter=',',
           header='y, XGB, SVM, RF, NB, LR, AlexNet, GoogLeNet, ShuffleNet, ViT, ResNet34, ResNet50, ResNet101, MobileNetV2, MobileNetV3_l, MobileNetV3_s, MobileViT_s, MobileViT_x_s, MobileViT_xx_s',
           comments='')
